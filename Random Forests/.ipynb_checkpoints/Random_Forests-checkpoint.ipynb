# %% [markdown]
#  RF usually provide better prediction accuracy over single Decision Trees and they tend to overfit less. Think of it as a **collection of Dicision Trees**
#
# **_How are RF are different from Single dicision Tree?_**
#
# -  A single DC have a good predictive capacities but can over on part of the data. When multiple trees are combined, their predictive power remains while they tend to overfit less by averaging their result.
#
# -  RF also provide randomness while creating different trees and the averaging of the results is done after.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

cancer=load_breast_cancer()
X_train,X_test,y_train,y_test=train_test_split(cancer.data,cancer.target,random_state=0)
forest=RandomForestClassifier(n_estimators=100, random_state=0) # n_estimater is the number of random trees in the RF
forest.fit(X_train,y_train)

print (forest.score(X_train,y_train))
print (forest.score(X_test,y_test))
# Out:
# 1.0
# 0.972027972028

# %% [markdown]
# Examine how the importance each feature of the tumor sample plays a role in deciding if the sample is predicted to be malignant or benign. _Feature importance_ is a parameter of our Random Forest classifier that we built and trained in the previous video with scikit-learn.

# %%
n_features=cancer.data.shape[1]
plt.barh(range(n_features),forest.feature_importances_,align='center')
plt.yticks(np.arange(n_features),cancer.feature_names)
plt.xlabel('Features Importance')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# Compare with the same plot in the previous notes. RF shows that more features are contributing in the classification compared to a single DT.

# %% [markdown]
# **Potential Advantages of Random Forests**
#
# -  Powerful and widely implemented.
# -  Perform well with default settings.
# -  Does not require scaling of the data.
# -  randomization makes them better than single DT.

# %% [markdown]
# **Parameters to Tune**
#
# -  n_jobs - number of cores to use for training (n_jobs=-1, for all cores)
# -  n_estimators - how many trees to use (more is always better)
# -  max_depth, for pre-pruning
# -  max_features, for randomization(default values below):
# > max_features = sqrt(n_features), for classification
# > max_features = log2(n_features), for regression
# -  etc.

# %% [markdown]
# **Potential Disadvantages of Random Forests**
#
# -  Does not performance well on very high dimensional and sparse data (text data).
# -  Large datasets require more resources for training (time, CPUs, etc).
# -  Cannot be visualized as well as single DT.
# -  Not got for intext processing.
